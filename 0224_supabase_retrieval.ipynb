# %% [markdown]
# <a href="https://colab.research.google.com/github/jessiechd/RAG_Model/blob/main/0224_supabase_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vecs --q

# %%
import vecs

DB_CONNECTION = "postgresql://postgres.###@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres"
vx = vecs.create_client(DB_CONNECTION)


chunks1 = vx.get_or_create_collection(name="chunks1", dimension=384)

# %%
# !pip install sentence-transformers --q

# %%
from sentence_transformers import SentenceTransformer

query = "What is medical training?"
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
query_embedding = model.encode(query).tolist()
print(query_embedding)
# Out:
# [0.001490715192630887, 0.08384770900011063, -0.05516750365495682, -0.008287861943244934, -0.03216809779405594, 0.0072563118301332, 0.015042564831674099, 0.054262589663267136, -0.04628853127360344, -0.039958979934453964, -0.051784418523311615, 0.035598501563072205, -0.011278060264885426, 0.02563079260289669, -0.0955752432346344, -0.06567806750535965, -0.0677853375673294, -0.04531519487500191, 0.01627480797469616, 0.03383810818195343, -0.025168675929307938, 0.07502450048923492, 0.02348511666059494, 0.07094340771436691, -0.011568516492843628, 0.01389347668737173, 0.01827845722436905, -0.02435174770653248, 0.019440339878201485, 0.038624051958322525, 0.09779052436351776, -0.03856224566698074, 0.061635930091142654, 0.01086137443780899, -0.018417490646243095, 0.07256640493869781, 0.0268272515386343, 0.016965599730610847, -0.05107289180159569, 0.09432370960712433, -0.04519864544272423, -0.021404284983873367, -0.0038214800879359245, 0.022482559084892273, 0.0790216326713562, 0.032615501433610916, -0.012376848608255386, -0.030296118929982185, -0.012608123943209648, 0.010728270746767521, -0.05922507867217064, -0.015609446913003922, -0.05793444439768791, 0.0557459332048893, 0.03559600189328194, -0.015590319409966469, 0.0024287973064929247, -0.050416216254234314, -0.12228263914585114, -0.0348442979156971, 0.001494992058724165, 0.02801540680229664, -0.007805805653333664, 0.010004034265875816, -0.022271117195487022, -0.07844002544879913, -0.033944759517908096, 0.005260880570858717, 0.07582352310419083, -0.13288269937038422, -0.028070790693163872, -0.058185137808322906, -0.007421743590384722, 0.09169532358646393, 0.02442292496562004, 0.05464089661836624, 0.035168640315532684, 0.0384308323264122, -0.015636172145605087, -0.06384319812059402, 0.04053890332579613, 0.04749253764748573, 0.024664225056767464, -0.011771307326853275, -0.02283724583685398, 0.007441218476742506, 0.0010749585926532745, 0.02683146670460701, -0.021729107946157455, -0.0002870693278964609, 0.04031509906053543, -0.022685036063194275, -0.05654319375753403, 0.002414582297205925, -0.02437267079949379, 0.024954400956630707, -0.030863167718052864, -0.021953189745545387, 0.0013631810434162617, 0.04527377709746361, 0.03102416917681694, -0.002965435152873397, -0.009402075782418251, 0.057137999683618546, -0.0329243429005146, -0.032794445753097534, -0.015727058053016663, -0.050217561423778534, 0.05605762079358101, -0.04874651879072189, 0.008852253668010235, 0.03691554069519043, -0.08090947568416595, -0.011581780388951302, -0.01101029571145773, 0.17392976582050323, -0.07942932844161987, -0.0376250334084034, -0.001735942205414176, 0.13707225024700165, -0.07523762434720993, -0.05094173178076744, -0.030742591246962547, -0.07694545388221741, 0.03649057075381279, -0.09725520014762878, -0.05986292287707329, -7.097845009880181e-33, 0.046572815626859665, -0.04296613857150078, 0.04567251354455948, -0.027147309854626656, 0.009366062469780445, -0.012017027474939823, 0.04617645964026451, -0.05409498140215874, 0.07374069094657898, -0.033531904220581055, -0.019929325208067894, 0.04760023579001427, 0.056451186537742615, 0.045175835490226746, 0.031149806454777718, 0.012263229116797447, -0.12922024726867676, 0.06410761177539825, 0.02422781102359295, 0.07588295638561249, 0.021180534735322, 0.015863940119743347, -0.06753706187009811, 0.0030618614982813597, -0.013516454957425594, 0.057827603071928024, -0.06453504413366318, 0.04381931573152542, 0.11663438379764557, -0.00021590788674075156, -0.05057469382882118, 0.0722307562828064, -0.009143589995801449, -0.0736439973115921, 0.01388874463737011, 0.05456366017460823, -0.04572016000747681, -0.029500922188162804, 0.038178522139787674, 0.007278631906956434, -0.002040322171524167, -0.05962477996945381, 0.07544231414794922, 0.012241164222359657, 0.045785337686538696, 0.07622786611318588, -0.004878298845142126, -0.09666205197572708, -0.09916968643665314, -0.009464136324822903, -0.02834339253604412, -0.07056046277284622, 0.02961958572268486, -0.08679439127445221, 0.0 ...

# %%
chunks1.query(
     data=query_embedding)

# ,
#     limit=1,                         # (optional) number of records to return
#     filters={"year": {"$eq": 1973}}, # (optional) metadata filters
#     measure="cosine_distance",       # (optional) distance measure to use
#     include_value=False,             # (optional) should distance measure values be returned?
#     include_metadata=False,          # (optional) should record metadata be returned?
# )
# Out:
# ['17.json_vec35',
#  '17.json_vec13',
#  '17.json_vec7',
#  '17.json_vec6',
#  '17.json_vec9',
#  '17.json_vec4',
#  '17.json_vec15',
#  '17.json_vec10',
#  '17.json_vec12',
#  '17.json_vec34']

# %%
query = "What is AI?"
query_embedding = model.encode(query).tolist()

chunks1.query(
     data=query_embedding)
# Out:
# ['ai-in-america-oai-economic-blueprint-20250113.json_vec17',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec3',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec8',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec18',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec25',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec21',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec16',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec13',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec26',
#  'ai-in-america-oai-economic-blueprint-20250113.json_vec23']
